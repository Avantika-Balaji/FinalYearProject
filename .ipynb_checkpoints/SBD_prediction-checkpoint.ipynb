# %%
# !pip install tensorflow
# !pip install ffmpeg-python
# !pip install pillow
# Out:
# Requirement already satisfied: tensorflow in c:\users\avant\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: gast==0.3.3 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: six~=1.15.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (3.7.4.2)
# Requirement already satisfied: wheel~=0.35 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\avant\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.24.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\avant\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\avant\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (53.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\avant\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\avant\appdata\roaming\python\python38\site-packages (from tensorboard~=2.4->tensorflow) (0.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\avant\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\avant\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\avant\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\avant\appdata\roaming\python\python38\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\avant\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\avant\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\avant\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\avant\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\avant\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\avant\appdata\roaming\python\python38\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: ffmpeg-python in c:\users\avant\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: future in c:\users\avant\anaconda3\lib\site-packages (from ffmpeg-python) (0.18.2)
# Requirement already satisfied: pillow in c:\users\avant\anaconda3\lib\site-packages (7.2.0)

# %%
import ffmpeg
import numpy as np
import tensorflow as tf
from sbd import Params, sbd
from transnet_utils import draw_video_with_predictions, scenes_from_predictions

# %%
# initialize the network
params = Params()
params.CHECKPOINT_PATH = "./model/transnet_model-F16_L3_S2_D256"
net = sbd(params)
# Out:
# Creating Build
#            Input (?, ?, 27, 48, 3)
#            SDDCNN_1
#            > DDCNN_1 (?, ?, 27, 48, 64)
#            > DDCNN_2 (?, ?, 27, 48, 64)
#            MaxPool (?, ?, 13, 24, 64)
#            SDDCNN_2
#            > DDCNN_1 (?, ?, 13, 24, 128)
#            > DDCNN_2 (?, ?, 13, 24, 128)
#            MaxPool (?, ?, 6, 12, 128)
#            SDDCNN_3
#            > DDCNN_1 (?, ?, 6, 12, 256)
#            > DDCNN_2 (?, ?, 6, 12, 256)
#            MaxPool (?, ?, 3, 6, 256)
#            Flatten (?, ?, 4608)
#            Dense (?, ?, 256)
#            Logits (?, ?, 2)
#            Predictions (?, ?)
# Network built.
# Found 9229700 trainable parameters.
# INFO:tensorflow:Restoring parameters from ./model/transnet_model-F16_L3_S2_D256
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
# -> 1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1360                                       target_list, run_metadata)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1450                           run_metadata):
# -> 1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
#
# NotFoundError: Key TransNet_1/SDDCNN_1/DDCNN_1/Conv3D_1/bias not found in checkpoint
# 	 [[{{node save_1/RestoreV2}}]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1296       else:
# -> 1297         sess.run(self.saver_def.restore_op_name,
#    1298                  {self.saver_def.filename_tensor_name: save_path})
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190       results = self._do_run(handle, final_targets, final_fetches,
#    1191                              feed_dict_tensor, options, run_metadata)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1367     if handle is None:
# -> 1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1369                            run_metadata)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1393                     'disable_meta_optimizer = True')
# -> 1394       raise type(e)(node_def, op, message)
#    1395
#
# NotFoundError: Key TransNet_1/SDDCNN_1/DDCNN_1/Conv3D_1/bias not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at C:\Users\avant\Desktop\SBD-Visualization\sbd.py:89) ]]
#
# Original stack trace for 'save_1/RestoreV2':
#   File "C:\Users\avant\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\avant\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\avant\anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\avant\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\avant\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\avant\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2866, in run_cell
#     result = self._run_cell(
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3071, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-64-f759804417ac>", line 4, in <module>
#     net = sbd(params)
#   File "C:\Users\avant\Desktop\SBD-Visualization\sbd.py", line 25, in __init__
#     self._restore()
#   File "C:\Users\avant\Desktop\SBD-Visualization\sbd.py", line 89, in _restore
#     saver = tf.train.Saver()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 835, in __init__
#     self.build()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 847, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 875, in _build
#     self.saver_def = self._builder._build_internal(  # pylint: disable=protected-access
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 514, in _build_internal
#     restore_op = self._AddRestoreOps(filename_tensor, saveables,
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 334, in _AddRestoreOps
#     all_tensors = self.bulk_restore(filename_tensor, saveables, preferred_shard,
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 582, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1507, in restore_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3528, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1990, in __init__
#     self._traceback = tf_stack.extract_stack()
#
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      68   try:
# ---> 69     return CheckpointReader.CheckpointReader_GetTensor(
#      70         self, compat.as_bytes(tensor_str))
#
# RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1307       try:
# -> 1308         names_to_keys = object_graph_key_mapping(save_path)
#    1309       except errors.NotFoundError:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saver.py in object_graph_key_mapping(checkpoint_path)
#    1625   reader = py_checkpoint_reader.NewCheckpointReader(checkpoint_path)
# -> 1626   object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
#    1627   object_graph_proto = (trackable_object_graph_pb2.TrackableObjectGraph())
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in get_tensor(self, tensor_str)
#      73   except RuntimeError as e:
# ---> 74     error_translator(e)
#      75
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in error_translator(e)
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#
# NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-64-f759804417ac> in <module>
#       2 params = Params()
#       3 params.CHECKPOINT_PATH = "./model/transnet_model-F16_L3_S2_D256"
# ----> 4 net = sbd(params)
#
# ~\Desktop\SBD-Visualization\sbd.py in __init__(self, params, session)
#      23         self.session = session or tf.Session()
#      24         self._build()
# ---> 25         self._restore()
#      26
#      27     def _build(self):
#
# ~\Desktop\SBD-Visualization\sbd.py in _restore(self)
#      88         if self.params.CHECKPOINT_PATH is not None:
#      89             saver = tf.train.Saver()
# ---> 90             saver.restore(self.session, self.params.CHECKPOINT_PATH)
#      91             print("Parameters restored from '{}'.".format(os.path.basename(self.params.CHECKPOINT_PATH)))
#      92
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\saver.py in restore(self, sess, save_path)
#    1311         # is a graph mismatch. Re-raise the original error with
#    1312         # a helpful message (b/110263146)
# -> 1313         raise _wrap_restore_error_with_msg(
#    1314             err, "a Variable name or other graph key that is missing")
#    1315
#
# NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:
#
# Key TransNet_1/SDDCNN_1/DDCNN_1/Conv3D_1/bias not found in checkpoint
# 	 [[node save_1/RestoreV2 (defined at C:\Users\avant\Desktop\SBD-Visualization\sbd.py:89) ]]
#
# Original stack trace for 'save_1/RestoreV2':
#   File "C:\Users\avant\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\avant\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\avant\anaconda3\lib\site-packages\traitlets\config\application.py", line 664, in launch_instance
#     app.start()
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 612, in start
#     self.io_loop.start()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\avant\anaconda3\lib\asyncio\base_events.py", line 570, in run_forever
#     self._run_once()
#   File "C:\Users\avant\anaconda3\lib\asyncio\base_events.py", line 1859, in _run_once
#     handle._run()
#   File "C:\Users\avant\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 543, in execute_request
#     self.do_execute(
#   File "C:\Users\avant\anaconda3\lib\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\avant\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2866, in run_cell
#     result = self._run_cell(
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3071, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\avant\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-64-f759804417ac>", line 4, in <module>
#     net = sbd(params)
#   File "C:\Users\avant\Desktop\SBD-Visualization\sbd.py", line 25, in __init__
#     self._restore()
#   File "C:\Users\avant\Desktop\SBD-Visualization\sbd.py", line 89, in _restore
#     saver = tf.train.Saver()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 835, in __init__
#     self.build()
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 847, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 875, in _build
#     self.saver_def = self._builder._build_internal(  # pylint: disable=protected-access
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 514, in _build_internal
#     restore_op = self._AddRestoreOps(filename_tensor, saveables,
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 334, in _AddRestoreOps
#     all_tensors = self.bulk_restore(filename_tensor, saveables, preferred_shard,
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\training\saver.py", line 582, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\ops\gen_io_ops.py", line 1507, in restore_v2
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 748, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3528, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\avant\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1990, in __init__
#     self._traceback = tf_stack.extract_stack()

# %%
# export video into numpy array using ffmpeg
video_stream, err = (
    ffmpeg
    .input('testing.mp4')
    .output('pipe:', format='rawvideo', pix_fmt='rgb24', s='{}x{}'.format(params.INPUT_WIDTH, params.INPUT_HEIGHT))
    .run(capture_stdout=True)
)
video = np.frombuffer(video_stream, np.uint8).reshape([-1, params.INPUT_HEIGHT, params.INPUT_WIDTH, 3])

# %%
# predict transitions using the neural network
predictions = net.predict_video(video)
# Out:
# Processing video frames 978/978

# %%
print(predictions.shape)
# Out:
# (978,)

# %%
# plot all 64 maps in an 8x8 squares
from matplotlib import pyplot as plt

for i in range(30, 35):
    square = 16
    ix = 1
    for _ in range(square):
        for _ in range(square):
            # specify subplot and turn of axis
            ax = plt.subplot(square, square, ix)
            ax.set_xticks([])
            ax.set_yticks([])
            # plot filter channel in grayscale
            plt.imshow(predictions[i, :, :, ix-1])
            #plt.imshow(predictions[0, :, :, ix-1])
            ix += 1
    # show the figure
    plt.show()
    
# square = 16
# ix = 1
# for _ in range(square):
#     for _ in range(square):
#             # specify subplot and turn of axis
#             ax = plt.subplot(square, square, ix)
#             ax.set_xticks([])
#             ax.set_yticks([])
#             # plot filter channel in grayscale
#             plt.imshow(predictions[530, :, :, ix-1])
#             #plt.imshow(predictions[0, :, :, ix-1])
#             ix += 1
#     # show the figure
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-dddeaa5673f7> in <module>
#      12             ax.set_yticks([])
#      13             # plot filter channel in grayscale
# ---> 14             plt.imshow(predictions[i, :, :, ix-1])
#      15             #plt.imshow(predictions[0, :, :, ix-1])
#      16             ix += 1
#
# IndexError: too many indices for array: array is 1-dimensional, but 4 were indexed

# %%
from matplotlib import pyplot as plt

plt.plot(predictions, marker='o', linestyle='--')
#plt.xlim(0,100)
plt.show()

# %%
# For ilustration purposes, we show only 200 frames starting with frame number 8000.
draw_video_with_predictions(video[:], predictions[:], threshold=0.1)
# Out:
# <PIL.Image.Image image mode=RGB size=960x1323 at 0x29EDBBEAD90>

# %%
# Generate list of scenes from predictions, returns tuples of (start frame, end frame)
scenes = scenes_from_predictions(predictions, threshold=0.1)

# For ilustration purposes, only the visualized scenes are shown.
scenes[:]
# Out:
# array([[  0,  28],
#        [ 29, 111],
#        [112, 180],
#        [181, 283],
#        [284, 360],
#        [361, 421],
#        [422, 504],
#        [505, 548],
#        [549, 640],
#        [641, 742],
#        [743, 777],
#        [778, 977]])

# %%
scenes[:]/25
# Out:
# array([[ 0.  ,  1.12],
#        [ 1.16,  4.44],
#        [ 4.48,  7.2 ],
#        [ 7.24, 11.32],
#        [11.36, 14.4 ],
#        [14.44, 16.84],
#        [16.88, 20.16],
#        [20.2 , 21.92],
#        [21.96, 25.6 ],
#        [25.64, 29.68],
#        [29.72, 31.08],
#        [31.12, 39.08]])

# %%
first_tran=scenes[1][1]

# %%
x=scenes[1][0]
y=scenes[1][1]

# %%
print(x,y)
# Out:
# 80 310

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.5.1.48-cp38-cp38-win_amd64.whl (34.9 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\avant\anaconda3\lib\site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.1.48

# %%
counter=111

# %%
counter
# Out:
# 283

# %%
import os
import glob

files = glob.glob('C:/Users/avant/Desktop/chainer-caption/sample_imgs/*.jpg')
for f in files:
    os.remove(f)

# %%
import cv2 

# Function to extract frames 
def FrameCapture(path): 
      
    # Path to video file 
    vidObj = cv2.VideoCapture(path) 
    # Used as counter variable 
    y=29
    count = 0
    # checks whether frames were extracted 
    success = 1
    while success: 
        
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
  
        # Saves the frames with frame-count 
        if(count<=counter and count%12==0 and count>=y):
            cv2.imwrite("C:/Users/avant/Desktop/chainer-caption/sample_imgs/frame%d.jpg" % count, image) 
        count += 1
  
# Driver Code 
if __name__ == '__main__': 
  
    # Calling the function 
    FrameCapture("elephants.mp4")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-c2c9bd23a6df> in <module>
#      26
#      27     # Calling the function
# ---> 28     FrameCapture("elephants.mp4")
#
# <ipython-input-71-c2c9bd23a6df> in FrameCapture(path)
#      15         # vidObj object calls read
#      16         # function extract frames
# ---> 17         success, image = vidObj.read()
#      18
#      19         # Saves the frames with frame-count
#
# KeyboardInterrupt:

# %%
import cv2 
  
# Function to extract frames 
def FrameCapture(path): 
      
    global counter
    # Path to video file 
    vidObj = cv2.VideoCapture(path) 
    # Used as counter variable 
    count = 0
    # checks whether frames were extracted 
    success = 1
  
    while success: 
  
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read() 
  
        # Saves the frames with frame-count 
#         if(count>=x and count<=y):
#             cv2.imwrite("frame%d.jpg" % count, image) 
        count += 1
    print(count)
    counter=count-1
  
# Driver Code 
if __name__ == '__main__': 
  
    # Calling the function 
    FrameCapture("testing.mp4")
# Out:
# 5040

# %%
# !ffmpeg -i test.mp4 -vf select='between(n,"$ x","$ y")' -vsync 0 frames%d.png
# Out:
# ffmpeg version 2021-01-05-git-66deab3a26-full_build-www.gyan.dev Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-lzma --enable-libsnappy --enable-zlib --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libdav1d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libmfx --enable-libglslang --enable-vulkan --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      56. 63.100 / 56. 63.100
#   libavcodec     58.115.102 / 58.115.102
#   libavformat    58. 65.101 / 58. 65.101
#   libavdevice    58. 11.103 / 58. 11.103
#   libavfilter     7. 95.100 /  7. 95.100
#   libswscale      5.  8.100 /  5.  8.100
#   libswresample   3.  8.100 /  3.  8.100
#   libpostproc    55.  8.100 / 55.  8.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'test.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2018-11-11T15:30:12.000000Z
#   Duration: 00:00:18.58, start: 0.000000, bitrate: 733 kb/s
#     Stream #0:0(und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(tv, bt709), 640x360 [SAR 1:1 DAR 16:9], 649 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2018-11-11T15:30:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/11/2018.
#       vendor_id       : [0][0][0][0]
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2018-11-11T15:30:12.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/11/2018.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# [Parsed_select_0 @ 0000017587f78000] [Eval @ 0000001cacbfe7f0] Undefined constant or missing '(' in '$x,$y)'
# [Parsed_select_0 @ 0000017587f78000] [Eval @ 0000001cacbfe7f0] Missing ')' or too many args in 'between(n,$x,$y)'
# [Parsed_select_0 @ 0000017587f78000] Error while parsing expression 'between(n,$ x,$ y)'
# [AVFilterGraph @ 0000017589d484c0] Error initializing filter 'select' with args 'between(n,$ x,$ y)'
# Error reinitializing filters!
# Failed to inject frame into filter network: Invalid argument
# Error while processing the decoded data for stream #0:0
# Conversion failed!
